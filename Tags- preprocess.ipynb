# %%
#top 10 tags based on freqency

import csv

TAGS =[]
tagstring =""
COUNTS=[]
VIEWS = []
UPVOTES =[]
ANSWERS =[]
YEAR =[]


with open('output.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    r = 0
    for row in reader:
        if r!= 0:
            taglist = row[4]
           
            if len(taglist) ==2 :
                continue
            else :   
                
                taglist = taglist.replace("[", "")
                taglist = taglist.replace("]", "")
                if "'" in taglist :
                    taglist = taglist.replace("'", "")
                tag = taglist.split(",")
                for i in range(len(tag)) :
                    
                    tag[i] = tag[i].strip()
                    
                    if tag[i] in TAGS :
                        tagstring = tagstring+ str(tag[i]) + ' '
                        index = TAGS.index(tag[i])
                        COUNTS[index] = COUNTS[index] +1 
                        VIEWS[index] = VIEWS[index] + int(row[2].replace(",",""))
                        UPVOTES[index] = UPVOTES[index] + int(row[1].replace(",",""))
                        ANSWERS[index] = ANSWERS[index] + int(row[3].replace(",",""))
                        
                        
                    else :
                        TAGS.append(tag[i])
                        COUNTS.append(1)
                        VIEWS.append(int(row[2].replace(",","")))
                        UPVOTES.append(int(row[1].replace(",","")))
                        ANSWERS.append(int(row[3].replace(",","")))
                        
                        
            
        r = r+1
            

csvFile.close()

print tagstring

outfile1 = open("counts.csv","w")
writer1 = csv.writer(outfile1, delimiter=",")
writer1.writerow(["Tag", "Counts"])

outfile2 = open("views.csv","w")
writer2 = csv.writer(outfile2, delimiter=",")
writer2.writerow(["Tag", "Views"])

outfile3 = open("votes.csv","w")
writer3 = csv.writer(outfile3, delimiter=",")
writer3.writerow(["Tag", "Votes"])

outfile4 = open("answers.csv","w")
writer4 = csv.writer(outfile4, delimiter=",")
writer4.writerow(["Tag", "Answers"])

for i in range(len(TAGS)) :
    writer1.writerow([TAGS[i], COUNTS[i]])
    writer2.writerow([TAGS[i], VIEWS[i]])
    writer3.writerow([TAGS[i], UPVOTES[i]])
    writer4.writerow([TAGS[i], ANSWERS[i]])
# Out:
# shiny ggplot2 devtools dataframe shiny rstudio data.table ggplot2 rstudio rstudio shinyapps dataframe data.table matrix dataframe shiny shiny dataframe matrix data.table reshape tidyr arrays prediction ggplot2 optimization plot histogram optimization dataframe time-series loops for-loop plot ggplot2 foreach dataframe aggregate plot text matrix lapply ggplot2 time-series matrix ggplot2 lapply regex plot ggplot2 gsub prediction reshape2 loops matrix for-loop dataframe dataframe missing-data arules histogram ggplot2 plot csv shiny ggplot2 string dataframe tidyr ggplot2 dataset regex facebook text arrays lapply na knitr data.table data.table tidyr ggplot2 loops plot devtools plot knitr r-markdown optimization dataframe median ggplot2 aggregate distance rename dataframe regex string plot ggplot2 heatmap dataframe shapefile dplyr r-markdown shiny-server algorithm colors ggplot2 plot sp r-raster random-forest tidyr ggplot2 dataframe tidyr ggplot2 shiny data.table html ggplot2 algorithm dplyr regex dataframe raster date python dplyr tidyr data.table function ggplot2 ggplot2 plotly regression loops dataframe multiple-columns quantmod csv shiny shiny-server shinyapps tidyr matrix dataframe tidyr dataframe dplyr rename function ggplot2 plot colors ggplot2 line-plot plot ggplot2 histogram density-plot csv data.table plot ggplot2 plyr ggplot2 time-series list knitr api if-statement regex ggplot2 javascript datatables shiny random-forest python dataframe data.table r-package dataset shiny ggplot2 shiny parallel-processing na apache-spark parallel-processing sparkr posix character-encoding rstudio dataframe dplyr ggplot2 ggplot2 string order ggplot2 data.table data.table for-loop aggregate rselenium facebook facebook-graph-api rvest data.table plot axis-labels web-scraping html-parsing apache-spark sparkr lapply python apache-spark weight ggplot2 shiny dplyr ggplot2 dplyr string statistics plot algorithm performance correlation data.table rpy2 javascript csv shiny regex gsub order text nlp matrix heatmap merge dplyr time-series dataframe shiny leaflet list dataframe date for-loop vectorization subset data.table time-series java pca merge apache-spark sparkr matrix rows rvest machine-learning xts shiny shiny ggvis aesthetics excel linux dataframe subset split merge dataframe datetime shiny pandoc dataframe matrix binary excel opencpu duplicates if-statement string shiny knitr r-markdown lines as.date osx-elcapitan string csv html regex xml regex gsub if-statement reference ggplot2 ggplot2 legend plot pca sapply csv dataframe dataframe apply apache-spark sparkr java classification foreach parallel-processing rvest raster shiny ggvis dataframe apply shiny shinyapps dplyr dataframe data.table geospatial arcgis plot ggplot2 ggplot2 plotly ggplot2 shiny ggvis dataframe ggplot2 legend ggplot2 time-series xts rstudio dplyr quantmod ggplot2 visualization date ggplot2 tm dataframe ggplot2 shiny plot function prediction python apache-spark pyspark rpy2 python indexing data.table dataframe interpolation missing-data random-forest macos plot ggplot2 sum machine-learning function dataframe postgresql spatial excel list dataframe data.table dplyr string dplyr function dataframe dplyr dataframe ggplot2 graphics ggplot2 label string performance bar-chart plotly json apache-spark matrix statistics dataframe dplyr subset excel excel-vba vba ggplot2 shiny rstudio r-markdown dataframe dplyr bar-chart axis-labels dataframe time-series dplyr data.table regex dplyr statistics python plot ggplot2 parallel-processing bioinformatics function plot regression prediction xts quantmod web web-scraping performance google-bigquery algorithm latex knitr ggplot2 shiny shinyapps ggplot2 plot ggplot2 list dplyr geospatial dataframe dplyr matrix interpolation date dataframe plyr data.table aggregate reshape2 unicode ggplot2 shiny facebook xts function transform optimization finance text-mining tm ggplot2 fonts if-statement lm neural-network time-series prediction forecasting plo ...

# %%
#user preprocess

import csv
USERS =[]
UCOUNTS=[]
UUPVOTES =[]



with open('output.csv', 'r') as csvFile2:
    reader2 = csv.reader(csvFile2)
    r = 0
    for row in reader2:
        if r!= 0:
            
            user = row[7]
            if user in USERS :
                index = USERS.index(user)
                UCOUNTS[index] = UCOUNTS[index] +1
            else:
                USERS.append(user)
                UCOUNTS.append(1)
        
        
        r = r+1    

csvFile2.close()


print len(USERS)    
UCOUNTS.sort(reverse= True)
print UCOUNTS[0:20]
# Out:
# 11958
# [180, 84, 78, 77, 76, 73, 65, 63, 62, 59, 53, 52, 49, 47, 44, 44, 42, 41, 40, 40]

# %%
# counts of tags by year

import csv
d ={}

with open('output.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    r = 0
    for row in reader:
        if r!= 0:
            taglist = row[4]
            year = row[5].strip()
            year = year.split("/")
            
            year = year[2]
            if len(taglist) ==2 :
                continue
            else :    
                taglist = taglist.replace("[", "")
                taglist = taglist.replace("]", "")
                if "'" in taglist :
                    taglist = taglist.replace("'", "")
                tag = taglist.split(",")                  
                for i in range(len(tag)):
                    if (tag[i] , year) in d:
                            d[(tag[i] , year)] += 1
                    else :
                        d[(tag[i] , year)] = 1
                        
        r = r+1
        
        
outfile5 = open("years.csv","w")
writer5 = csv.writer(outfile5, delimiter=",")
writer5.writerow(["Tag","Year", "Counts"])
for i in d :
    writer5.writerow([i[0], i[1], d[i] ])

# %%
d15 ={}
for i in d :
    if i[1] == '15' :
         d15[i] = d[i]
